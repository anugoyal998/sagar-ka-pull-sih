# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 kB 10.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/sih/fire-detection
# Out:
# /content/drive/MyDrive/sih/fire-detection

# %%
video_path = "/content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4"
model_path = "/content/drive/MyDrive/sih/fire-detection/fire-smoke.pt"

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/sih/fire-detection/fire-smoke.pt" source="/content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4" save=True
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients
#
# video 1/1 (1/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 95.1ms
# video 1/1 (2/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 15.8ms
# video 1/1 (3/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 15.4ms
# video 1/1 (4/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 15.4ms
# video 1/1 (5/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 15.4ms
# video 1/1 (6/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 15.4ms
# video 1/1 (7/4349) /content/drive/MyDrive/sih/fire-detection/fire-smoke-test.mp4: 480x800 (no detections), 15.4ms
# ...

# %%
import cv2
from ultralytics import YOLO

model = YOLO(model_path)

cap = cv2.VideoCapture(video_path)

while True:
  ret, frame = cap.read()
  if ret:
    results = model(frame)

  else:
    break

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/detections.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
